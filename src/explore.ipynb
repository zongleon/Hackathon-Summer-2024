# %%
import pandas as pd
import dask.dataframe as dd

# %%
DATA_PATH = "../data/Tab_delimited_text/"
ATAC_FILE = "Hackathon2024.ATAC.txt"
META_FILE = "Hackathon2024.Meta.txt"
RNA_FILE = "Hackathon2024.RNA.txt"
TRAIN_FILE = "Hackathon2024.Training.Set.Peak2Gene.Pairs.txt"
TEST_FILE = "Hackathon2024.Testing.Set.Peak2Gene.Pairs.txt"

atac_df = dd.read_csv(DATA_PATH + ATAC_FILE, sep="\t")
meta_df = dd.read_csv(DATA_PATH + META_FILE, sep="\t")
rna_df  = dd.read_csv(DATA_PATH + RNA_FILE, sep="\t")
train_df = dd.read_csv(DATA_PATH + TRAIN_FILE, sep="\t")

# %%
atac_df.head()
# Out:
#                  peak  AAACCAACACAATGCC.1  AAACCAACAGGAACTG.1  \
# 0    chr1-10109-10357                   0                   0
# 1  chr1-180730-181630                   0                   0
# 2  chr1-191491-191736                   0                   0
# 3  chr1-267816-268196                   0                   2
# 4  chr1-586028-586373                   0                   0
#
#    AAACCAACATAATCCG.1  AAACCAACATTGTGCA.1  AAACCGCGTACTTCAC.1  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0
#
#    AAACCGGCATAATCAC.1  AAACGCGCAGCAAGAT.1  AAACGGATCCCATAGG.1  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# ...

# %%
rna_df.head()
# Out:
#           gene  AAACCAACACAATGCC.1  AAACCAACAGGAACTG.1  AAACCAACATAATCCG.1  \
# 0  MIR1302-2HG                   0                   0                   0
# 1      FAM138A                   0                   0                   0
# 2        OR4F5                   0                   0                   0
# 3   AL627309.1                   0                   0                   0
# 4   AL627309.3                   0                   0                   0
#
#    AAACCAACATTGTGCA.1  AAACCGCGTACTTCAC.1  AAACCGGCATAATCAC.1  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0
#
#    AAACGCGCAGCAAGAT.1  AAACGGATCCCATAGG.1  AAAGCAAGTGCTAGCG.1  ...  \
# 0                   0                   0                   0  ...
# ...

# %%
meta_df.head()
# Out:
#                     nCount_RNA  nCount_ATAC   CellType
# AAACCAACACAATGCC-1        5849        16550  CD14 Mono
# AAACCAACAGGAACTG-1        5901        25593  CD14 Mono
# AAACCAACATAATCCG-1        7975        42743  CD14 Mono
# AAACCAACATTGTGCA-1        5525        21760  CD14 Mono
# AAACCGCGTACTTCAC-1       10327        76652  CD14 Mono

# %%
train_df.head()
# Out:
#                        peak      gene                              Pair  \
# 0    chr1-89196985-89201657      GBP2       chr1-89196985-89201657_GBP2
# 1    chr6-33077557-33083333  HLA-DPA1   chr6-33077557-33083333_HLA-DPA1
# 2  chr6-137789753-137792920   TNFAIP3  chr6-137789753-137792920_TNFAIP3
# 3  chr1-212604203-212626574      ATF3     chr1-212604203-212626574_ATF3
# 4    chr2-96541661-96555628    ARID5A     chr2-96541661-96555628_ARID5A
#
#    Peak2Gene
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True

# %%
test_df = dd.read_csv(DATA_PATH + "Hackathon2024.Testing.Set.Peak2Gene.Pairs.txt", sep="\t")

# %%
test_df.head()
# Out:
#                      peak    gene                         Pair Peak2Gene
# 0    chr1-1245493-1248050    SDF4    chr1-1245493-1248050_SDF4         ?
# 1    chr1-1330394-1334148  MRPL20  chr1-1330394-1334148_MRPL20         ?
# 2    chr1-2145904-2147150  FAAP20  chr1-2145904-2147150_FAAP20         ?
# 3    chr1-9713011-9736481  PIK3CD  chr1-9713011-9736481_PIK3CD         ?
# 4  chr1-21287896-21301043    ECE1  chr1-21287896-21301043_ECE1         ?

# %%
p = "chr1-89196985-89201657"
g = "GBP2"

# %%
atac_df[atac_df["peak"] == p].compute()
# Out:
#                         peak  AAACCAACACAATGCC.1  AAACCAACAGGAACTG.1  \
# 4445  chr1-89196985-89201657                   0                   0
#
#       AAACCAACATAATCCG.1  AAACCAACATTGTGCA.1  AAACCGCGTACTTCAC.1  \
# 4445                   0                   0                   0
#
#       AAACCGGCATAATCAC.1  AAACGCGCAGCAAGAT.1  AAACGGATCCCATAGG.1  \
# 4445                   0                   2                   0
#
#       AAAGCAAGTGCTAGCG.1  ...  TTTGTCCCAGTAGGAT.1  TTTGTCTAGCTATTAG.1  \
# 4445                   0  ...                   2                   0
#
#       TTTGTCTAGGACCTGC.1  TTTGTGAAGCGATACT.1  TTTGTGAAGGAACGGT.1  \
# 4445                   0                   0                   0
#
#       TTTGTGGCAGCAACCT.1  TTTGTGTTCATTGACA.1  TTTGTGTTCGTCAAGT.1  \
# 4445                   2                   0                   0
#
#       TTTGTGTTCTCCATAT.1  TTTGTTGGTCAGGAAG.1
# 4445                   0                   0
#
# [1 rows x 3000 columns]

# %%
atac_df.to_parquet(DATA_PATH + "atac/")

# %%
rna_df.to_parquet(DATA_PATH + "rna/")
